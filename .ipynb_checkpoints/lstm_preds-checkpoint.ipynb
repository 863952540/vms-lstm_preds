# %%
import tensorflow as tf
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score
from tensorflow.keras import utils,losses,layers,Sequential
from tensorflow.keras.callbacks import ModelCheckpoint,TensorBoard
import matplotlib.image as mpimg 
from tensorflow.keras.utils import plot_model
import pydotplus

# %%
data_path="./get_data/TemperatureData_New.csv"
dataset=pd.read_csv(data_path,parse_dates=['Dates'],index_col=['Dates'])
#dataset.head()#数据结构如下，输出头5个列
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3658 entries, 2013-01-01 to 2022-12-31
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Tem_Low   3658 non-null   int64
#  1   Tem_High  3658 non-null   int64
#  2   WP_Night  3658 non-null   float64
#  3   WP_Day    3658 non-null   float64
# dtypes: float64(2), int64(2)
# memory usage: 142.9 KB

# %%
days = [0, 0, 31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]

#df["month_cos"] = [np.cos(x.month * (2 * np.pi / 12)) for x in df['Dates']]
#df["month_sin"] = [np.sin(x.month * (2 * np.pi / 12)) for x in df['Dates']]
dataset["day_cos"] = [np.cos((x.day + sum(days[1:x.month])) * (2 * np.pi / 365)) for x in dataset.index]
dataset["day_sin"] = [np.sin((x.day + sum(days[1:x.month])) * (2 * np.pi / 365)) for x in dataset.index]
dataset['month']=dataset.index.month
dataset.head()
# Out:
#             Tem_Low  Tem_High  WP_Night  WP_Day   day_cos   day_sin  month
# Dates
# 2013-01-01       -3         5       3.5     3.5  0.999852  0.017213      1
# 2013-01-02       -5         1       5.5     5.5  0.999407  0.034422      1
# 2013-01-03       -5        -1       4.5     3.5  0.998667  0.051620      1
# 2013-01-04       -3         1       3.5     3.5  0.997630  0.068802      1
# 2013-01-05       -3         3       3.5     3.0  0.996298  0.085965      1

# %%
#future=['day_cos','day_sin','month','Tem_Low','Tem_High']
#定义切分函数，x是选取的特征组成的例表，y是标签列（x=dataset[future=] ，y=dataset['Tem_Low']）
#train_dataset,train_labels=multivariate_data(x_train,y_train,0,1466,3,1,1,True)
#上面的一个使用的意思就是：从0开始数到10万，按照3条x数据作为一个元素放入data-》1条y数据作为一个元素存入labels，step=1表示
#每一条数据就按照上面包装一次，比如data[0]=x[0，1，2]->labels[0]=y[3];data[1]=x[1,2,3]->labels[1]=y[4];
#single_step意思是只预测目标的一个未来状态，只预测后1小时，设置为false可以预测未来0到target_size小时内的温度。
def multivariate_data(x,y, start_index, end_index, history_size,
                      target_size, step, single_step):
    data = []
    labels = []

    start_index = start_index + history_size
    
    if end_index is None:
        end_index = len(dataset) - target_size

    for i in range(start_index, end_index):
        indices = range(i-history_size, i, step) # step表示滑动步长
        mid_data=x.iloc[indices]
        data.append(mid_data.values)

        if single_step:
            mid_data=y.iloc[i+target_size]
            labels.append(mid_data)
        else:
            labels.append(y.iloc[i:i+target_size])

    return np.array(data), np.array(labels)

# %%
future=['day_cos','day_sin','month','Tem_Low','Tem_High']
#数据归一化，由于sin和cos本来就是-1到1，不用归一化
# for col in future:
#     scaler=MinMaxScaler()
#     if(col not in ['day_cos','day_sin']):
#     	dataset[col]=scaler.fit_transform(dataset[col].values.reshape(-1,1))
# dataset.head()

normalize_info = {
	"Tem_Low": {
		"Name": "Tem_Low_Normalize",
		"Tem_Low_Max": 0,
		"Tem_Low_Min": 0,
        "Tem_Low_Dist": 0,
        "Tem_Low_Mean": 0,
	}
}
for col in future:
    if(col not in ['day_cos','day_sin']):
        _max = dataset[col].max()
        _min = dataset[col].min()
        _mean = dataset[col].mean()
        dist = _max - _min
        if(col == 'Tem_Low'):
            normalize_info[col]["Tem_Low_Max"] = _max
            normalize_info[col]["Tem_Low_Min"] = _min
            normalize_info[col]["Tem_Low_Mean"] = _mean
            normalize_info[col]["Tem_Low_Dist"] = dist
            dataset[normalize_info[col]["Name"]] = dataset[col].apply(lambda x:(x-_mean)/dist)
        else:
    	    dataset[col] = dataset[col].apply(lambda x:(x-_mean)/dist)
dataset.head()
# Out:
#             Tem_Low  Tem_High  WP_Night  WP_Day   day_cos   day_sin     month  \
# Dates
# 2013-01-01       -3 -0.359699       3.5     3.5  0.999852  0.017213 -0.502137
# 2013-01-02       -5 -0.448588       5.5     5.5  0.999407  0.034422 -0.502137
# 2013-01-03       -5 -0.493032       4.5     3.5  0.998667  0.051620 -0.502137
# 2013-01-04       -3 -0.448588       3.5     3.5  0.997630  0.068802 -0.502137
# 2013-01-05       -3 -0.404143       3.5     3.0  0.996298  0.085965 -0.502137
#
#             Tem_Low_Normalize
# Dates
# 2013-01-01          -0.405966
# 2013-01-02          -0.455966
# 2013-01-03          -0.455966
# 2013-01-04          -0.405966
# 2013-01-05          -0.405966

# %%
normalize_info["Tem_Low"]["Tem_Low_Min"]
# Out:
# -9

# %%
# start_index=0
# end_index=1466
# history_size=10
# target_size=1
# step=1
# train_data,train_label=multivariate_data(dataset, start_index, end_index, history_size,target_size, step)

#获取训练特征和训练标签

future_new = ['Tem_Low_Normalize','Tem_High', 'day_cos','day_sin','month']
x=dataset[future_new]
y=dataset['Tem_Low_Normalize']
x.head()
# Out:
#             Tem_Low_Normalize  Tem_High   day_cos   day_sin     month
# Dates
# 2013-01-01          -0.405966 -0.359699  0.999852  0.017213 -0.502137
# 2013-01-02          -0.455966 -0.448588  0.999407  0.034422 -0.502137
# 2013-01-03          -0.455966 -0.493032  0.998667  0.051620 -0.502137
# 2013-01-04          -0.405966 -0.448588  0.997630  0.068802 -0.502137
# 2013-01-05          -0.405966 -0.404143  0.996298  0.085965 -0.502137

# %%
test_length = int(y.shape[0]*2/3)
test_length
# Out:
# 2438

# %%
y.shape[0]-test_length
# Out:
# 1220

# %%
#通过2:1划分训练集和测试集，2/3为训练集
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,shuffle=False,random_state=13)

x_train.shape
# Out:
# (2450, 5)

# %%
#取得训练集，和测试集的格式——》(3,4)->(1,)通过3行历史数据5列目标特征预测1行1列的目标
# multivariate_data(x,y, start_index, end_index, history_size,target_size, step, single_step)
train_dataset,train_labels=multivariate_data(x_train,y_train,0,2450-10,10,7,1,False)
test_dataset,test_labels=multivariate_data(x_test,y_test,0,y.shape[0]-2450-10,10,7,1,False)

# %%
train_dataset.shape
# Out:
# (2430, 10, 5)

# %%
#创建训练组，内部的batch_size，buffer_size，shuffle，batch建议百度
#该函数目标是把刚建好的训练集/测试集转化成tensorflow的数据集格式，打乱分组方便训练模型......
def create_batch_dataset(x,y,train=True,buffer_size=1000,batch_size=128):
    batch_data=tf.data.Dataset.from_tensor_slices((tf.constant(x),tf.constant(y)))
    if train:
        return batch_data.cache().shuffle(buffer_size).batch(batch_size)
    else:
        return batch_data.batch(batch_size)
       
        
#使用上面函数
train_batch_dataset=create_batch_dataset(train_dataset,train_labels)
test_batch_dataset=create_batch_dataset(test_dataset,test_labels,train=False)
#拿一个测试集元素查看格式
list(test_batch_dataset.as_numpy_iterator())[0]
# Out:
# (array([[[ 0.16903362,  0.17363465, -0.70862668, -0.70558361,
#            0.22513544],
#          [ 0.21903362,  0.17363465, -0.69637623, -0.71767691,
#            0.22513544],
#          [ 0.09403362,  0.19585687, -0.68391942, -0.72955755,
#            0.22513544],
#          ...,
#          [ 0.04403362,  0.12919021, -0.6186714 , -0.78564986,
#            0.22513544],
#          [ 0.14403362,  0.19585687, -0.60505607, -0.79618286,
#            0.22513544],
#          [ 0.14403362,  0.19585687, -0.59126144, -0.80647995,
#            0.22513544]],
#
#         [[ 0.21903362,  0.17363465, -0.69637623, -0.71767691,
#            0.22513544],
#          [ 0.09403362,  0.19585687, -0.68391942, -0.72955755,
#            0.22513544],
#          [ 0.11903362,  0.10696798, -0.67125996, -0.74122201,
#            0.22513544],
#          ...,
#          [ 0.14403362,  0.19585687, -0.60505607, -0.79618286,
#            0.22513544],
#          [ 0.14403362,  0.19585687, -0.59126144, -0.80647995,
#            0.22513544],
#          [ 0.14403362,  0.10696798, -0.57729162, -0.81653805,
#            0.22513544]],
#
#         [[ 0.09403362,  0.19585687, -0.68391942, -0.72955755,
#            0.22513544],
#          [ 0.11903362,  0.10696798, -0.67125996, -0.74122201,
#            0.22513544],
#          [ 0.11903362,  0.12919021, -0.65840158, -0.75266683,
#            0.22513544],
#          ...,
#          [ 0.14403362,  0.19585687, -0.59126144, -0.80647995,
#            0.22513544],
#          [ 0.14403362,  0.10696798, -0.57729162, -0.81653805,
#            0.22513544],
#          [ 0.14403362,  0.12919021, -0.56315072, -0.8263542 ,
#            0.22513544]],
#
#         ...,
#
#         [[-0.35596638, -0.24858757,  0.94698775,  0.32126966,
#           -0.50213728],
#          [-0.33096638, -0.24858757,  0.94131732,  0.3375229 ,
#           -0.50213728],
#          [-0.25596638, -0.29303202,  0.93536795,  0.35367612,
#           -0.50213728],
#          ...,
#          [-0.25596638, -0.33747646,  0.90150168,  0.43277559,
#           -0.50213728],
#          [-0.28096638, -0.33747646,  0.8939186 ,  0.44822934,
#           -0.50213728],
#          [-0.33096638, -0.33747646,  0.88607062,  0.46355027,
#           -0.50213728]],
#
#         [[-0.33096638, -0.24858757,  0.94131732,  0.3375229 ,
#           -0.50213728],
#          -0.25596638, -0.28096638],
#         [-0.35596638, -0.35596638, -0.23096638, -0.23096638, -0.25596638,
#          -0.28096638, -0.28096638],
#         [-0.35596638, -0.23096638, -0.23096638, -0.25596638, -0.28096638,
#          -0.28096638, -0.25596638]]))

# %%
#建立神经网络模型-3层LSTM和一个输出层
model= tf.keras.models.Sequential([
    tf.keras.layers.LSTM(8, input_shape=(10, 5), return_sequences=True), # input_shape=(20,1) 不包含批处理维度
#     tf.keras.layers.Dropout(0.4),
#     tf.keras.layers.LSTM(128, return_sequences=True),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.LSTM(4),
    tf.keras.layers.Dense(1)
])

#优化器和损失函数设置
model.compile(optimizer='adam',loss='mse')

#模型保存的相关设置
utils.plot_model(model)
checkpoint_file='test_model.hdf5'
checkpoint_callback=ModelCheckpoint(filepath=checkpoint_file,monitor='loss',moode='min',save_best_only=True,save_weights_only=True)
#模型训练
history=model.fit(train_batch_dataset,epochs=30,validation_data=test_batch_dataset,callbacks=[checkpoint_callback])
# Out:
# Train for 19 steps, validate for 10 steps
# Epoch 1/30
# 19/19 [==============================] - 2s 124ms/step - loss: 0.0842 - val_loss: 0.0652
# Epoch 2/30
# 19/19 [==============================] - 0s 8ms/step - loss: 0.0527 - val_loss: 0.0375
# Epoch 3/30
# 19/19 [==============================] - 0s 9ms/step - loss: 0.0283 - val_loss: 0.0159
# Epoch 4/30
# 19/19 [==============================] - 0s 10ms/step - loss: 0.0126 - val_loss: 0.0086
# Epoch 5/30
# 19/19 [==============================] - 0s 10ms/step - loss: 0.0090 - val_loss: 0.0077
# Epoch 6/30
# 19/19 [==============================] - 0s 8ms/step - loss: 0.0084 - val_loss: 0.0075
# Epoch 7/30
# 19/19 [==============================] - 0s 9ms/step - loss: 0.0079 - val_loss: 0.0073
# Epoch 8/30
# 19/19 [==============================] - 0s 9ms/step - loss: 0.0078 - val_loss: 0.0073
# Epoch 9/30
# 19/19 [==============================] - 0s 9ms/step - loss: 0.0075 - val_loss: 0.0073
# Epoch 10/30
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0074 - val_loss: 0.0071
# Epoch 11/30
# 19/19 [==============================] - 0s 8ms/step - loss: 0.0073 - val_loss: 0.0071
# Epoch 12/30
# 19/19 [==============================] - 0s 8ms/step - loss: 0.0073 - val_loss: 0.0073
# Epoch 13/30
# 19/19 [==============================] - 0s 10ms/step - loss: 0.0071 - val_loss: 0.0072
# Epoch 14/30
# 19/19 [==============================] - 0s 8ms/step - loss: 0.0071 - val_loss: 0.0072
# Epoch 15/30
# 19/19 [==============================] - 0s 8ms/step - loss: 0.0070 - val_loss: 0.0071
# Epoch 16/30
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0068 - val_loss: 0.0072
# Epoch 17/30
# 19/19 [==============================] - 0s 8ms/step - loss: 0.0069 - val_loss: 0.0071
# Epoch 18/30
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0069 - val_loss: 0.0072
# Epoch 19/30
# 19/19 [==============================] - 0s 9ms/step - loss: 0.0067 - val_loss: 0.0072
# Epoch 20/30
# 19/19 [==============================] - 0s 9ms/step - loss: 0.0067 - val_loss: 0.0071
# Epoch 21/30
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0067 - val_loss: 0.0071
# Epoch 22/30
# 19/19 [==============================] - 0s 10ms/step - loss: 0.0066 - val_loss: 0.0071
# Epoch 23/30
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0066 - val_loss: 0.0070
# Epoch 24/30
# 19/19 [==============================] - 0s 8ms/step - loss: 0.0064 - val_loss: 0.0072
# Epoch 25/30
# 19/19 [==============================] - 0s 8ms/step - loss: 0.0063 - val_loss: 0.0071
# Epoch 26/30
# 19/19 [==============================] - 0s 8ms/step - loss: 0.0063 - val_loss: 0.0071
# Epoch 27/30
# 19/19 [==============================] - 0s 8ms/step - loss: 0.0064 - val_loss: 0.0071
# Epoch 28/30
# 19/19 [==============================] - 0s 8ms/step - loss: 0.0065 - val_loss: 0.0071
# Epoch 29/30
# 19/19 [==============================] - 0s 8ms/step - loss: 0.0063 - val_loss: 0.0072
# Epoch 30/30
# 19/19 [==============================] - 0s 10ms/step - loss: 0.0062 - val_loss: 0.0071

# %%
#最喜欢的绘图环节，通过history获取模型每步训练取得的结果loss和val_loss
plt.figure(figsize=(8,8),dpi=200)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model train vs validation loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train','validation'], loc='best')
plt.show()

# %%
test_dataset.shape
# Out:
# (1188, 10, 5)

# %%
#通过输入一组数据预测
test_preds=model.predict(test_dataset,verbose=1)
test_preds[:10]
# Out:
# 1188/1188 [==============================] - 0s 395us/sample
# array([[0.12962782],
#        [0.12504128],
#        [0.12007137],
#        [0.11600409],
#        [0.11398857],
#        [0.11138931],
#        [0.10708294],
#        [0.10278135],
#        [0.10008605],
#        [0.09560402]], dtype=float32)

# %%
#将预测后的一组数据转化为1维方便比较
test_preds=test_preds[:,0]
#test_preds[:10]

# %%
#pred = np.insert(test_dataset, 13, values=test_preds, axis=1)
# df_preds = pd.DataFrame(test_preds)
# test_inverse = scaler.inverse_transform(df_preds.values)
# test_inverse
reverse_preds = [i*(normalize_info["Tem_Low"]["Tem_Low_Max"]-normalize_info["Tem_Low"]["Tem_Low_Min"])+normalize_info["Tem_Low"]["Tem_Low_Mean"]  for i in test_preds]
reverse_preds
# Out:
# [18.42376795591977,
#  18.240306051394015,
#  18.041509659906893,
#  17.87881848396924,
#  17.798197837492495,
#  17.694227369448214,
#  17.52197262825635,
#  17.34990891995099,
#  17.242096932550936,
#  17.062815697809725,
#  16.827442916056185,
#  16.664443882128268,
#  16.39393058600095,
#  16.050449879786044,
#  15.655751647373704,
#  15.287639172693757,
#  14.949626000544098,
#  14.614665629288224,
#  14.247160972973374,
#  13.880435796400574,
#  13.799976976534394,
#  13.592328997274903,
#  13.457640530487565,
#  13.282047631165055,
#  13.018039287945298,
#  12.692570509335068,
#  12.464640708586243,
#  12.254950972219971,
#  12.033964963575867,
#  11.913777859827546,
#  11.873684199472931,
#  11.751408250948456,
#  11.544290156981019,
#  11.292815776487855,
#  11.052373917719391,
#  10.801226766726044,
#  10.546101601740387,
#  10.33644136967328,
#  10.127197476049927,
#  9.935532780310181,
#  9.749567182680634,
#  9.728876324316529,
#  9.645428033491639,
#  9.454835625311402,
#  9.216061802526978,
#  8.949413867613343,
#  8.6752843576875,
#  8.387368889471558,
#  8.084925087114838,
#  7.837215335985688,
#  7.673498066088227,
#  7.517976434847382,
#  7.382244737764863,
#  7.207448156496552,
#  7.036137254854706,
#  6.858524950167206,
#  6.58345189871457,
#  6.242972286364106,
#  6.0175153333154,
#  5.838749082705048,
#  5.651838453432587,
#  5.3626617509331975,
#  5.070976884981659,
#  4.757630499025849,
#  4.619424017092255,
#  4.431843431612519,
#  4.145370395800141,
#  3.795880945345429,
#  3.4101852494683538,
#  3.034099014421967,
#  2.7960416394677434,
#  2.780807884356049,
#  2.651006849428681,
#  2.6292046624627385,
#  2.565118940493134,
#  2.506360681673554,
#  2.465612562319306,
#  2.4515446740594182,
#  2.4706276971307073,
#  2.4704667645898137,
#  2.4244531709161077,
#  2.398837478777436,
#  2.4382742959466253,
#  2.403570087572602,
#  2.3588260728326116,
#  2.222028644701508,
#  2.0563146192040715,
#  1.9429024774041448,
#  1.788451345583466,
#  1.5877338963952337,
#  1.425798805376557,
#  1.2571713048424993,
#  1.0608538705315862,
#  1.0353347379174505,
#  1.0532495099511419,
#  1.0679539758172307,
#  1.0798522550072942,
#  1.0518595296349798,
#  1.0841330605950628,
#  6.977948816439179,
#  7.382030161043671,
#  7.832647236010102,
#  8.186221988817719,
#  8.520850511213807,
#  8.98110506119397,
#  9.441515775343445,
#  9.71603211941388,
#  9.742556186338929,
#  9.635236235281495,
#  9.403664441725281,
#  9.068375797888306,
#  8.66086420597699,
#  8.369403453489808,
#  8.260251851698426,
#  8.254908295294312,
#  8.27434477390912,
#  8.62167176785138,
#  8.925437899252442,
#  9.281680555960206,
#  9.708018274923829,
#  10.092407436987427,
#  10.337811382433442,
#  10.500086219927338,
#  10.570582421442536,
#  10.687067480703858,
#  10.836366685053376,
#  11.061695488115815,
#  11.351028056761292,
#  11.607561977526215,
#  11.914011808058289,
#  12.391285570284394,
#  12.868773313185242,
#  13.260685624500779,
#  13.593551488539246,
#  13.82704657497075,
#  13.969736220261124,
#  13.985777767321137,
#  13.978385003229645,
#  13.905086638351944,
#  13.843364538570908,
#  13.841054411551026,
#  13.851640196463135,
#  13.974459739347962,
#  14.282152624746827,
#  14.581556888243226,
#  14.87697658123639,
#  15.165850790163544,
#  15.379493208548096,
#  15.533774765154389,
#  15.649097235819367,
#  15.72889667930272,
#  15.78254458489087,
#  15.804177196642426,
#  15.907829077860383,
#  16.014954419752627,
#  16.22306373896268,
#  16.465691002031832,
#  16.755154700895815,
#  17.0708235818353,
#  17.402299614569216,
#  17.715578051229983,
#  17.900750013014346,
#  18.021103711744814,
#  18.080867500921755,
#  18.130498798510104,
#  18.17010608496335,
#  18.205302329679995,
#  18.263873727938204,
#  18.394658239504366,
#  18.54517546476987,
#  18.728258283754855,
#  18.913104208132296,
#  19.11034491839078,
#  19.29634300055173,
#  19.499395759722262,
#  19.702317388674288,
#  19.85149470152524,
#  20.00316944899228,
#  20.11474457564023,
#  20.29820886435178,
#  20.41212168516782,
#  20.521605880877047,
#  20.632772119661837,
#  20.78017082991269,
#  20.94851103605893,
#  21.114527853151827,
#  21.325819166323214,
#  21.486136587282687,
#  21.65016380133298,
#  21.837821872850924,
#  22.025215299746066,
#  22.166785867830782,
#  22.23490920843747,
#  22.288973005434542,
#  22.38096442999509,
#  22.480344446321993,
#  22.615749509951144,
#  ...]

# %%
len(reverse_preds)
# Out:
# 1188

# %%
test_value = dataset['Tem_Low'].values[2450:-20]
len(test_value)
# Out:
# 1188

# %%
#计算MAE
mae = 0
for i in range(1188):
    mae+=abs(reverse_preds[i]-test_value[i])
mae/1188
# Out:
# 2.8479975975029377

# %%
#计算MSE
mse = 0;
temp = 0;
for i in range(1188):
    temp = abs(reverse_preds[i]-test_value[i])
    mse+=pow(temp, 2)
mse/=1188
mse
# Out:
# 13.030040930569244

# %%
#r2检验，越接近1效果越好，负数表示完全没用......
score=r2_score(test_labels,test_preds)
score
# Out:
# 0.8526079675970792

# %%
#做出预测结果和实际结果的曲线对比，使用1000次结果对比
plt.figure(figsize=(16,8))
plt.plot(test_value[:1000],label="True value")
plt.plot(reverse_preds[:1000],label="Pred value")
plt.legend(loc='best')
plt.show()
