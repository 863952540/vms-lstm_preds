# %%
import tensorflow as tf
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score
from tensorflow.keras import utils,losses,layers,Sequential
from tensorflow.keras.callbacks import ModelCheckpoint,TensorBoard

# %%
data_path="./数据获取/TemperatureData.csv"
dataset=pd.read_csv(data_path,parse_dates=['Dates'],index_col=['Dates'])
#dataset.head()#数据结构如下，输出头5个列
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1466 entries, 2019-01-01 to 2022-12-31
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Tem_Low   1466 non-null   int64
#  1   Tem_High  1466 non-null   int64
# dtypes: int64(2)
# memory usage: 34.4 KB

# %%
days = [0, 0, 31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]

#df["month_cos"] = [np.cos(x.month * (2 * np.pi / 12)) for x in df['Dates']]
#df["month_sin"] = [np.sin(x.month * (2 * np.pi / 12)) for x in df['Dates']]
dataset["day_cos"] = [np.cos((x.day + sum(days[1:x.month])) * (2 * np.pi / 365)) for x in dataset.index]
dataset["day_sin"] = [np.sin((x.day + sum(days[1:x.month])) * (2 * np.pi / 365)) for x in dataset.index]
dataset['month']=dataset.index.month
dataset.head()
# Out:
#             Tem_Low  Tem_High   day_cos   day_sin  month
# Dates
# 2019-01-01       -2         5  0.999852  0.017213      1
# 2019-01-02        0         4  0.999407  0.034422      1
# 2019-01-03        3         8  0.998667  0.051620      1
# 2019-01-04        4         7  0.997630  0.068802      1
# 2019-01-05        3         5  0.996298  0.085965      1

# %%
#future=['day_cos','day_sin','month','Tem_Low','Tem_High']
#定义切分函数，x是选取的特征组成的例表，y是标签列（x=dataset[future=] ，y=dataset['Tem_Low']）
#train_dataset,train_labels=multivariate_data(x_train,y_train,0,1466,3,1,1,True)
#上面的一个使用的意思就是：从0开始数到10万，按照3条x数据作为一个元素放入data-》1条y数据作为一个元素存入labels，step=1表示
#每一条数据就按照上面包装一次，比如data[0]=x[0，1，2]->labels[0]=y[3];data[1]=x[1,2,3]->labels[1]=y[4];
#single_step意思是只预测目标的一个未来状态，只预测后1小时，设置为false可以预测未来0到target_size小时内的温度。
def multivariate_data(x,y, start_index, end_index, history_size,
                      target_size, step, single_step):
    data = []
    labels = []

    start_index = start_index + history_size
    
    if end_index is None:
        end_index = len(dataset) - target_size

    for i in range(start_index, end_index):
        indices = range(i-history_size, i, step) # step表示滑动步长
        mid_data=x.iloc[indices]
        data.append(mid_data.values)

        if single_step:
            mid_data=y.iloc[i+target_size]
            labels.append(mid_data)
        else:
            labels.append(y.iloc[i:i+target_size])

    return np.array(data), np.array(labels)

# %%
future=['day_cos','day_sin','month','Tem_Low','Tem_High']
#数据归一化，由于sin和cos本来就是-1到1，不用归一化
# for col in future:
#     scaler=MinMaxScaler()
#     if(col not in ['day_cos','day_sin']):
#     	dataset[col]=scaler.fit_transform(dataset[col].values.reshape(-1,1))
# dataset.head()

normalize_info = {
	"Tem_Low": {
		"Name": "Tem_Low_Normalize",
		"Tem_Low_Max": 0,
		"Tem_Low_Min": 0,
        "Tem_Low_Dist": 0,
	}
}
for col in future:
    if(col not in ['day_cos','day_sin']):
        _max = dataset[col].max()
        _min = dataset[col].min()
        dist = _max - _min
        if(col == 'Tem_Low'):
            normalize_info[col]["Tem_Low_Max"] = _max
            normalize_info[col]["Tem_Low_Min"] = _min
            normalize_info[col]["Tem_Low_Dist"] = dist
            dataset[normalize_info[col]["Name"]] = dataset[col].apply(lambda x:(x-_min)/dist)
        else:
    	    dataset[col] = dataset[col].apply(lambda x:(x-_min)/dist)
dataset.head()
# Out:
#             Tem_Low  Tem_High   day_cos   day_sin  month  Tem_Low_Normalize
# Dates
# 2019-01-01       -2  0.204545  0.999852  0.017213    0.0           0.131579
# 2019-01-02        0  0.181818  0.999407  0.034422    0.0           0.184211
# 2019-01-03        3  0.272727  0.998667  0.051620    0.0           0.263158
# 2019-01-04        4  0.250000  0.997630  0.068802    0.0           0.289474
# 2019-01-05        3  0.204545  0.996298  0.085965    0.0           0.263158

# %%
normalize_info["Tem_Low"]["Tem_Low_Min"]
# Out:
# -7

# %%
# start_index=0
# end_index=1466
# history_size=10
# target_size=1
# step=1
# train_data,train_label=multivariate_data(dataset, start_index, end_index, history_size,target_size, step)

#获取训练特征和训练标签

future_new = ['day_cos','day_sin','month','Tem_Low_Normalize','Tem_High']
x=dataset[future_new]
y=dataset['Tem_Low_Normalize']
x.head()
# Out:
#              day_cos   day_sin  month  Tem_Low_Normalize  Tem_High
# Dates
# 2019-01-01  0.999852  0.017213    0.0           0.131579  0.204545
# 2019-01-02  0.999407  0.034422    0.0           0.184211  0.181818
# 2019-01-03  0.998667  0.051620    0.0           0.263158  0.272727
# 2019-01-04  0.997630  0.068802    0.0           0.289474  0.250000
# 2019-01-05  0.996298  0.085965    0.0           0.263158  0.204545

# %%
test_length = int(y.shape[0]*2/3)
test_length
# Out:
# 977

# %%
y.shape[0]-test_length
# Out:
# 489

# %%
#通过2:1划分训练集和测试集，2/3为训练集
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,shuffle=False,random_state=13)

x_train.shape
# Out:
# (982, 5)

# %%
#取得训练集，和测试集的格式——》(3,4)->(1,)通过3行历史数据5列目标特征预测1行1列的目标
# multivariate_data(x,y, start_index, end_index, history_size,target_size, step, single_step)
train_dataset,train_labels=multivariate_data(x_train,y_train,0,982-10,10,7,1,True)
test_dataset,test_labels=multivariate_data(x_test,y_test,0,y.shape[0]-982-10,10,7,1,True)

# %%
train_dataset.shape
# Out:
# (962, 10, 5)

# %%
#创建训练组，内部的batch_size，buffer_size，shuffle，batch建议百度
#该函数目标是把刚建好的训练集/测试集转化成tensorflow的数据集格式，打乱分组方便训练模型......
def create_batch_dataset(x,y,train=True,buffer_size=1000,batch_size=128):
    batch_data=tf.data.Dataset.from_tensor_slices((tf.constant(x),tf.constant(y)))
    if train:
        return batch_data.cache().shuffle(buffer_size).batch(batch_size)
    else:
        return batch_data.batch(batch_size)
       
        
#使用上面函数
train_batch_dataset=create_batch_dataset(train_dataset,train_labels)
test_batch_dataset=create_batch_dataset(test_dataset,test_labels,train=False)
#拿一个测试集元素查看格式
list(test_batch_dataset.as_numpy_iterator())[0]
# Out:
# (array([[[-0.83827971, -0.54524044,  0.72727273,  0.86842105,
#            0.77272727],
#          [-0.82877009, -0.55958926,  0.72727273,  0.78947368,
#            0.79545455],
#          [-0.81901489, -0.57377227,  0.72727273,  0.78947368,
#            0.75      ],
#          ...,
#          [-0.76665882, -0.64205471,  0.72727273,  0.81578947,
#            0.81818182],
#          [-0.75549331, -0.65515636,  0.72727273,  0.81578947,
#            0.79545455],
#          [-0.74410394, -0.66806386,  0.72727273,  0.81578947,
#            0.72727273]],
#
#         [[-0.82877009, -0.55958926,  0.72727273,  0.78947368,
#            0.79545455],
#          [-0.81901489, -0.57377227,  0.72727273,  0.78947368,
#            0.75      ],
#          [-0.80901699, -0.58778525,  0.72727273,  0.73684211,
#            0.70454545],
#          ...,
#          [-0.75549331, -0.65515636,  0.72727273,  0.81578947,
#            0.79545455],
#          [-0.74410394, -0.66806386,  0.72727273,  0.81578947,
#            0.72727273],
#          [-0.73249407, -0.68077341,  0.72727273,  0.76315789,
#            0.75      ]],
#
#         [[-0.81901489, -0.57377227,  0.72727273,  0.78947368,
#            0.75      ],
#          [-0.80901699, -0.58778525,  0.72727273,  0.73684211,
#            0.70454545],
#          [-0.79877937, -0.60162406,  0.72727273,  0.78947368,
#            0.72727273],
#          ...,
#          [-0.74410394, -0.66806386,  0.72727273,  0.81578947,
#            0.72727273],
#          [-0.73249407, -0.68077341,  0.72727273,  0.76315789,
#            0.75      ],
#          [-0.72066715, -0.69328123,  0.72727273,  0.76315789,
#            0.77272727]],
#
#         ...,
#
#         [[ 0.99274872,  0.12020804,  0.        ,  0.18421053,
#            0.29545455],
#          [ 0.99053245,  0.13727877,  0.        ,  0.28947368,
#            0.29545455],
#          [ 0.98802267,  0.15430882,  0.        ,  0.23684211,
#            0.29545455],
#          ...,
#          [ 0.97110005,  0.23867277,  0.        ,  0.13157895,
#            0.20454545],
#          [ 0.96684781,  0.2553533 ,  0.        ,  0.23684211,
#            0.31818182],
#          [ 0.96230908,  0.27195816,  0.        ,  0.28947368,
#            0.34090909]],
#
#         [[ 0.99053245,  0.13727877,  0.        ,  0.28947368,
#            0.29545455],
#          [ 0.98802267,  0.15430882,  0.        ,  0.23684211,
#            0.29545455],
#          [ 0.98522011,  0.17129314,  0.        ,  0.21052632,
#            0.27272727],
#          ...,
#          [ 0.96684781,  0.2553533 ,  0.        ,  0.23684211,
#            0.31818182],
#          [ 0.96230908,  0.27195816,  0.        ,  0.28947368,
#            0.34090909],
#          [ 0.95748519,  0.28848243,  0.        ,  0.23684211,
#            0.36363636]],
#
#         [[ 0.98802267,  0.15430882,  0.        ,  0.23684211,
#            0.29545455],
#          [ 0.98522011,  0.17129314,  0.        ,  0.21052632,
#            0.27272727],
#          [ 0.98212561,  0.18822671,  0.        ,  0.13157895,
#            0.22727273],
#          ...,
#          [ 0.96230908,  0.27195816,  0.        ,  0.28947368,
#            0.34090909],
#          [ 0.95748519,  0.28848243,  0.        ,  0.23684211,
#            0.36363636],
#          [ 0.95237758,  0.30492122,  0.        ,  0.23684211,
#            0.36363636]]]),
#  array([0.73684211, 0.76315789, 0.76315789, 0.76315789, 0.76315789,
#         0.76315789, 0.78947368, 0.81578947, 0.65789474, 0.65789474,
#         0.73684211, 0.81578947, 0.78947368, 0.78947368, 0.73684211,
#         0.78947368, 0.78947368, 0.76315789, 0.76315789, 0.63157895,
#         0.60526316, 0.65789474, 0.76315789, 0.65789474, 0.57894737,
#         0.39473684, 0.42105263, 0.42105263, 0.5       , 0.44736842,
#         0.42105263, 0.44736842, 0.5       , 0.5       , 0.47368421,
#         0.52631579, 0.55263158, 0.5       , 0.52631579, 0.5       ,
#         0.52631579, 0.55263158, 0.52631579, 0.52631579, 0.60526316,
#         0.63157895, 0.60526316, 0.23684211, 0.21052632, 0.31578947,
#         0.31578947, 0.31578947, 0.36842105, 0.34210526, 0.34210526,
#         0.42105263, 0.39473684, 0.44736842, 0.44736842, 0.44736842,
#         0.55263158, 0.31578947, 0.15789474, 0.23684211, 0.28947368,
#         0.26315789, 0.34210526, 0.39473684, 0.44736842, 0.39473684,
#         0.15789474, 0.13157895, 0.21052632, 0.23684211, 0.26315789,
#         0.31578947, 0.31578947, 0.34210526, 0.39473684, 0.31578947,
#         0.31578947, 0.39473684, 0.18421053, 0.21052632, 0.31578947,
#         0.44736842, 0.26315789, 0.10526316, 0.15789474, 0.23684211,
#         0.28947368, 0.26315789, 0.28947368, 0.34210526, 0.15789474,
#         0.07894737, 0.05263158, 0.13157895, 0.15789474, 0.10526316,
#         0.15789474, 0.21052632, 0.15789474, 0.18421053, 0.23684211,
#         0.34210526, 0.23684211, 0.18421053, 0.18421053, 0.28947368,
#         0.23684211, 0.21052632, 0.13157895, 0.15789474, 0.10526316,
#         0.13157895, 0.23684211, 0.28947368, 0.23684211, 0.23684211,
#         0.23684211, 0.18421053, 0.28947368, 0.34210526, 0.26315789,
#         0.21052632, 0.26315789, 0.28947368]))

# %%
#建立神经网络模型-3层LSTM和一个输出层
model= tf.keras.models.Sequential([
    tf.keras.layers.LSTM(256, input_shape=train_dataset.shape[-2:],return_sequences=True), # input_shape=(20,1) 不包含批处理维度
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.LSTM(128, return_sequences=True),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.LSTM(32),
    tf.keras.layers.Dense(1)
])

#优化器和损失函数设置
model.compile(optimizer='adam',loss='mse')

#模型保存的相关设置
utils.plot_model(model)
checkpoint_file='test_model.hdf5'
checkpoint_callback=ModelCheckpoint(filepath=checkpoint_file,monitor='loss',moode='min',save_best_only=True,save_weights_only=True)
#模型训练
history=model.fit(train_batch_dataset,epochs=30,validation_data=test_batch_dataset,callbacks=[checkpoint_callback])
# Out:
# Failed to import pydot. You must install pydot and graphviz for `pydotprint` to work.
# Train for 8 steps, validate for 4 steps
# Epoch 1/30
# 8/8 [==============================] - 4s 547ms/step - loss: 0.1046 - val_loss: 0.0140
# Epoch 2/30
# 8/8 [==============================] - 1s 67ms/step - loss: 0.0196 - val_loss: 0.0106
# Epoch 3/30
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0107 - val_loss: 0.0099
# Epoch 4/30
# 8/8 [==============================] - 1s 65ms/step - loss: 0.0089 - val_loss: 0.0105
# Epoch 5/30
# 8/8 [==============================] - 1s 68ms/step - loss: 0.0075 - val_loss: 0.0103
# Epoch 6/30
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0071 - val_loss: 0.0099
# Epoch 7/30
# 8/8 [==============================] - 1s 68ms/step - loss: 0.0069 - val_loss: 0.0100
# Epoch 8/30
# 8/8 [==============================] - 1s 72ms/step - loss: 0.0069 - val_loss: 0.0095
# Epoch 9/30
# 8/8 [==============================] - 1s 70ms/step - loss: 0.0066 - val_loss: 0.0096
# Epoch 10/30
# 8/8 [==============================] - 1s 71ms/step - loss: 0.0068 - val_loss: 0.0095
# Epoch 11/30
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0064 - val_loss: 0.0095
# Epoch 12/30
# 8/8 [==============================] - 1s 67ms/step - loss: 0.0065 - val_loss: 0.0095
# Epoch 13/30
# 8/8 [==============================] - 1s 71ms/step - loss: 0.0064 - val_loss: 0.0095
# Epoch 14/30
# 8/8 [==============================] - 1s 71ms/step - loss: 0.0064 - val_loss: 0.0095
# Epoch 15/30
# 8/8 [==============================] - 1s 68ms/step - loss: 0.0065 - val_loss: 0.0093
# Epoch 16/30
# 8/8 [==============================] - 1s 74ms/step - loss: 0.0067 - val_loss: 0.0097
# Epoch 17/30
# 8/8 [==============================] - 1s 70ms/step - loss: 0.0068 - val_loss: 0.0095
# Epoch 18/30
# 8/8 [==============================] - 1s 65ms/step - loss: 0.0066 - val_loss: 0.0095
# Epoch 19/30
# 8/8 [==============================] - 1s 75ms/step - loss: 0.0064 - val_loss: 0.0095
# Epoch 20/30
# 8/8 [==============================] - 1s 67ms/step - loss: 0.0064 - val_loss: 0.0095
# Epoch 21/30
# 8/8 [==============================] - 1s 70ms/step - loss: 0.0063 - val_loss: 0.0095
# Epoch 22/30
# 8/8 [==============================] - 1s 70ms/step - loss: 0.0062 - val_loss: 0.0093
# Epoch 23/30
# 8/8 [==============================] - 1s 64ms/step - loss: 0.0063 - val_loss: 0.0095
# Epoch 24/30
# 8/8 [==============================] - 1s 73ms/step - loss: 0.0063 - val_loss: 0.0095
# Epoch 25/30
# 8/8 [==============================] - 1s 65ms/step - loss: 0.0065 - val_loss: 0.0094
# Epoch 26/30
# 8/8 [==============================] - 1s 68ms/step - loss: 0.0062 - val_loss: 0.0096
# Epoch 27/30
# 8/8 [==============================] - 1s 67ms/step - loss: 0.0063 - val_loss: 0.0097
# Epoch 28/30
# 8/8 [==============================] - 1s 65ms/step - loss: 0.0064 - val_loss: 0.0096
# Epoch 29/30
# 8/8 [==============================] - 1s 74ms/step - loss: 0.0062 - val_loss: 0.0094
# Epoch 30/30
# 8/8 [==============================] - 1s 66ms/step - loss: 0.0064 - val_loss: 0.0095

# %%
#最喜欢的绘图环节，通过history获取模型每步训练取得的结果loss和val_loss
plt.figure(figsize=(8,8),dpi=200)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model train vs validation loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train','validation'], loc='best')
plt.show()

# %%
test_dataset.shape
# Out:
# (464, 10, 5)

# %%
#通过输入一组数据预测
test_preds=model.predict(test_dataset,verbose=1)
test_preds[:10]
# Out:
# 464/464 [==============================] - 1s 2ms/sample
# array([[0.7287606 ],
#        [0.72319824],
#        [0.7193194 ],
#        [0.71533936],
#        [0.712645  ],
#        [0.70790285],
#        [0.70272774],
#        [0.6968343 ],
#        [0.69005615],
#        [0.68369544]], dtype=float32)

# %%
#将预测后的一组数据转化为1维方便比较
test_preds=test_preds[:,0]
#        0.4942604 , 0.48715463, 0.4836992 , 0.48360246, 0.4801323 ,
#        0.4744873 , 0.47505307, 0.4766921 , 0.47600684, 0.47316828,
#        0.46845022, 0.4636943 , 0.45927832, 0.4525343 , 0.45250973,
#        0.4532389 , 0.4510638 , 0.44449037, 0.4406189 , 0.43396825,
#        0.43405983, 0.43132293, 0.42563143, 0.4211267 , 0.41506597,
#        0.40909818, 0.40500468, 0.39942327, 0.39492187, 0.3947899 ,
#        0.3960502 , 0.3944375 , 0.39631644, 0.3943508 , 0.38942766,
#        0.3820546 , 0.37176907, 0.36309323, 0.3527458 , 0.34045824,
#        0.3372304 , 0.34046403, 0.34724376, 0.35347727, 0.35616675,
#        0.35627475, 0.35418287, 0.34935006, 0.34330645, 0.33091265,
#        0.3164195 , 0.30118188, 0.28416264, 0.2642958 , 0.24481453,
#        0.22382475, 0.21125385, 0.21679392, 0.22791311, 0.23520237,
#        0.23978259, 0.2389374 , 0.23766151, 0.23867975, 0.2373217 ,
#        0.22840825, 0.21627595, 0.20221527, 0.19863059], dtype=float32)

# %%
#pred = np.insert(test_dataset, 13, values=test_preds, axis=1)
# df_preds = pd.DataFrame(test_preds)
# test_inverse = scaler.inverse_transform(df_preds.values)
# test_inverse
reverse_preds = [i*(normalize_info["Tem_Low"]["Tem_Low_Max"]-normalize_info["Tem_Low"]["Tem_Low_Min"])+normalize_info["Tem_Low"]["Tem_Low_Min"]  for i in test_preds]
reverse_preds
# Out:
# [20.69290280342102,
#  20.48153293132782,
#  20.334137320518494,
#  20.18289577960968,
#  20.080509781837463,
#  19.90030825138092,
#  19.703653931617737,
#  19.4797043800354,
#  19.22213351726532,
#  18.9804265499115,
#  18.779194712638855,
#  18.64146602153778,
#  18.50069773197174,
#  18.455307602882385,
#  18.349111914634705,
#  18.248850464820862,
#  18.07192862033844,
#  17.972976326942444,
#  17.77990972995758,
#  17.55148684978485,
#  17.342175841331482,
#  17.172963976860046,
#  17.049846649169922,
#  16.916613936424255,
#  16.73708736896515,
#  16.521724343299866,
#  16.507192254066467,
#  16.439265608787537,
#  16.197003722190857,
#  15.793779015541077,
#  15.393272280693054,
#  14.98616087436676,
#  14.61571490764618,
#  14.134753942489624,
#  13.59389340877533,
#  13.01330292224884,
#  12.330654859542847,
#  11.771589577198029,
#  11.312553584575653,
#  10.730110347270966,
#  9.983714520931244,
#  9.445601403713226,
#  9.135863602161407,
#  9.20956140756607,
#  9.27867716550827,
#  9.34027773141861,
#  9.286101758480072,
#  9.37468272447586,
#  9.460896790027618,
#  9.501145422458649,
#  9.456264913082123,
#  9.415370762348175,
#  9.435969591140747,
#  9.394555628299713,
#  9.332077383995056,
#  9.30459076166153,
#  9.106925129890442,
#  8.80278068780899,
#  8.351198732852936,
#  7.7733805775642395,
#  7.246096312999725,
#  6.709201753139496,
#  6.090303719043732,
#  5.515222787857056,
#  5.053977310657501,
#  5.233620524406433,
#  5.634153306484222,
#  5.810699164867401,
#  5.988175928592682,
#  6.133111774921417,
#  6.071724116802216,
#  5.920670568943024,
#  5.6835275292396545,
#  22.839119791984558,
#  22.478825449943542,
#  22.082812428474426,
#  21.82065498828888,
#  21.600200295448303,
#  21.35225784778595,
#  21.131141781806946,
#  20.99800193309784,
#  20.863009333610535,
#  20.695086240768433,
#  20.654359698295593,
#  20.6181902885437,
#  20.54712665081024,
#  20.445379376411438,
#  20.279356598854065,
#  20.13936972618103,
#  19.978413701057434,
#  19.72428333759308,
#  19.427401542663574,
#  19.229589819908142,
#  19.112963914871216,
#  18.922436356544495,
#  18.66281569004059,
#  18.331195950508118,
#  18.053740859031677,
#  17.77273428440094,
#  17.535165429115295,
#  17.258949279785156,
#  16.95550811290741,
#  16.648703455924988,
#  16.506802678108215,
#  16.466642379760742,
#  16.462368369102478,
#  16.441942811012268,
#  16.606762886047363,
#  16.721776127815247,
#  16.669215083122253,
#  16.47597634792328,
#  16.123319506645203,
#  15.757657170295715,
#  15.208721995353699,
#  14.46553111076355,
#  13.540245175361633,
#  12.561304211616516,
#  11.781895220279694,
#  11.511876046657562,
#  11.380569696426392,
#  11.376893639564514,
#  11.245027840137482,
#  11.030517578125,
#  11.052016735076904,
#  11.114300191402435,
#  11.088259756565094,
#  10.980394780635834,
#  10.801108300685883,
#  10.620383560657501,
#  10.452575981616974,
#  10.196302950382233,
#  10.19536978006363,
#  10.2230783700943,
#  10.140424847602844,
#  9.890634179115295,
#  9.7435182929039,
#  9.490793347358704,
#  9.494273483753204,
#  9.390271425247192,
#  9.173994481563568,
#  9.00281435251236,
#  8.772507011890411,
#  8.545730769634247,
#  8.390177845954895,
#  8.178084313869476,
#  8.00703102350235,
#  8.002016365528107,
#  8.04990816116333,
#  7.988624691963196,
#  8.060024678707123,
#  7.985330283641815,
#  7.798251152038574,
#  7.518074691295624,
#  7.127224683761597,
#  6.797542631626129,
#  6.404340445995331,
#  5.937413275241852,
#  5.814755737781525,
#  5.937632977962494,
#  6.1952627301216125,
#  6.432136237621307,
#  6.534336507320404,
#  6.538440644741058,
#  6.458949029445648,
#  6.275302469730377,
#  6.045645177364349,
#  5.574680685997009,
#  5.023941457271576,
#  4.444911539554596,
#  3.798180341720581,
#  3.0432398915290833,
#  2.302952140569687,
#  1.5053406655788422,
#  1.0276463627815247,
#  1.2381691336631775,
#  1.6606982350349426,
#  1.9376901388168335,
#  2.111738294363022,
#  2.0796209275722504,
#  2.0311374068260193,
#  2.0698305666446686,
#  2.018224775791168,
#  1.679513394832611,
#  1.2184859216213226,
#  0.6841802299022675,
#  0.5479622781276703]

# %%
len(reverse_preds)
# Out:
# 464

# %%
test_value = dataset['Tem_Low'].values[982:-20]
len(test_value)
# Out:
# 464

# %%
sum = 0
for i in range(464):
    sum+=abs(reverse_preds[i]-test_value[i])
sum/464
# Out:
# 3.268568775841388

# %%
#r2检验，越接近1效果越好，负数表示完全没用......
score=r2_score(test_labels,test_preds)
score
# Out:
# 0.8526079675970792

# %%
#做出预测结果和实际结果的曲线对比，使用1000次结果对比
plt.figure(figsize=(16,8))
plt.plot(test_value[:1000],label="True value")
plt.plot(reverse_preds[:1000],label="Pred value")
plt.legend(loc='best')
plt.show()
