# %%
import tensorflow as tf
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score
from tensorflow.keras import utils,losses,layers,Sequential
from tensorflow.keras.callbacks import ModelCheckpoint,TensorBoard

# %%
data_path="./数据获取/TemperatureData_New.csv"
dataset=pd.read_csv(data_path,parse_dates=['Dates'],index_col=['Dates'])
#dataset.head()#数据结构如下，输出头5个列
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3658 entries, 2013-01-01 to 2022-12-31
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Tem_Low   3658 non-null   int64
#  1   Tem_High  3658 non-null   int64
#  2   WP_Night  3658 non-null   float64
#  3   WP_Day    3658 non-null   float64
# dtypes: float64(2), int64(2)
# memory usage: 142.9 KB

# %%
days = [0, 0, 31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]

#df["month_cos"] = [np.cos(x.month * (2 * np.pi / 12)) for x in df['Dates']]
#df["month_sin"] = [np.sin(x.month * (2 * np.pi / 12)) for x in df['Dates']]
dataset["day_cos"] = [np.cos((x.day + sum(days[1:x.month])) * (2 * np.pi / 365)) for x in dataset.index]
dataset["day_sin"] = [np.sin((x.day + sum(days[1:x.month])) * (2 * np.pi / 365)) for x in dataset.index]
dataset['month']=dataset.index.month
dataset.head()
# Out:
#             Tem_Low  Tem_High  WP_Night  WP_Day   day_cos   day_sin  month
# Dates
# 2013-01-01       -3         5       3.5     3.5  0.999852  0.017213      1
# 2013-01-02       -5         1       5.5     5.5  0.999407  0.034422      1
# 2013-01-03       -5        -1       4.5     3.5  0.998667  0.051620      1
# 2013-01-04       -3         1       3.5     3.5  0.997630  0.068802      1
# 2013-01-05       -3         3       3.5     3.0  0.996298  0.085965      1

# %%
#future=['day_cos','day_sin','month','Tem_Low','Tem_High']
#定义切分函数，x是选取的特征组成的例表，y是标签列（x=dataset[future=] ，y=dataset['Tem_Low']）
#train_dataset,train_labels=multivariate_data(x_train,y_train,0,1466,3,1,1,True)
#上面的一个使用的意思就是：从0开始数到10万，按照3条x数据作为一个元素放入data-》1条y数据作为一个元素存入labels，step=1表示
#每一条数据就按照上面包装一次，比如data[0]=x[0，1，2]->labels[0]=y[3];data[1]=x[1,2,3]->labels[1]=y[4];
#single_step意思是只预测目标的一个未来状态，只预测后1小时，设置为false可以预测未来0到target_size小时内的温度。
def multivariate_data(x,y, start_index, end_index, history_size,
                      target_size, step, single_step):
    data = []
    labels = []

    start_index = start_index + history_size
    
    if end_index is None:
        end_index = len(dataset) - target_size

    for i in range(start_index, end_index):
        indices = range(i-history_size, i, step) # step表示滑动步长
        mid_data=x.iloc[indices]
        data.append(mid_data.values)

        if single_step:
            mid_data=y.iloc[i+target_size]
            labels.append(mid_data)
        else:
            labels.append(y.iloc[i:i+target_size])

    return np.array(data), np.array(labels)

# %%
future=['day_cos','day_sin','month','Tem_Low','Tem_High', 'WP_Night', 'WP_Day']
#数据归一化，由于sin和cos本来就是-1到1，不用归一化
# for col in future:
#     scaler=MinMaxScaler()
#     if(col not in ['day_cos','day_sin']):
#     	dataset[col]=scaler.fit_transform(dataset[col].values.reshape(-1,1))
# dataset.head()

normalize_info = {
	"Tem_Low": {
		"Name": "Tem_Low_Normalize",
		"Tem_Low_Max": 0,
		"Tem_Low_Min": 0,
        "Tem_Low_Dist": 0,
	}
}
for col in future:
    if(col not in ['day_cos','day_sin']):
        _max = dataset[col].max()
        _min = dataset[col].min()
        dist = _max - _min
        if(col == 'Tem_Low'):
            normalize_info[col]["Tem_Low_Max"] = _max
            normalize_info[col]["Tem_Low_Min"] = _min
            normalize_info[col]["Tem_Low_Dist"] = dist
            dataset[normalize_info[col]["Name"]] = dataset[col].apply(lambda x:(x-_min)/dist)
        else:
    	    dataset[col] = dataset[col].apply(lambda x:(x-_min)/dist)
dataset.head()
# Out:
#             Tem_Low  Tem_High  WP_Night    WP_Day   day_cos   day_sin  month  \
# Dates
# 2013-01-01       -3  0.222222  0.333333  0.333333  0.999852  0.017213    0.0
# 2013-01-02       -5  0.133333  0.666667  0.666667  0.999407  0.034422    0.0
# 2013-01-03       -5  0.088889  0.500000  0.333333  0.998667  0.051620    0.0
# 2013-01-04       -3  0.133333  0.333333  0.333333  0.997630  0.068802    0.0
# 2013-01-05       -3  0.177778  0.333333  0.250000  0.996298  0.085965    0.0
#
#             Tem_Low_Normalize
# Dates
# 2013-01-01               0.15
# 2013-01-02               0.10
# 2013-01-03               0.10
# 2013-01-04               0.15
# 2013-01-05               0.15

# %%
normalize_info["Tem_Low"]["Tem_Low_Min"]
# Out:
# -9

# %%
# start_index=0
# end_index=1466
# history_size=10
# target_size=1
# step=1
# train_data,train_label=multivariate_data(dataset, start_index, end_index, history_size,target_size, step)

#获取训练特征和训练标签

future_new = ['Tem_Low_Normalize','Tem_High', 'WP_Night', 'WP_Day',  'day_cos','day_sin','month']
x=dataset[future_new]
y=dataset['Tem_Low_Normalize']
x.head()
# Out:
#             Tem_Low_Normalize  Tem_High  WP_Night    WP_Day   day_cos  \
# Dates
# 2013-01-01               0.15  0.222222  0.333333  0.333333  0.999852
# 2013-01-02               0.10  0.133333  0.666667  0.666667  0.999407
# 2013-01-03               0.10  0.088889  0.500000  0.333333  0.998667
# 2013-01-04               0.15  0.133333  0.333333  0.333333  0.997630
# 2013-01-05               0.15  0.177778  0.333333  0.250000  0.996298
#
#              day_sin  month
# Dates
# 2013-01-01  0.017213    0.0
# 2013-01-02  0.034422    0.0
# 2013-01-03  0.051620    0.0
# 2013-01-04  0.068802    0.0
# 2013-01-05  0.085965    0.0

# %%
train_length = int(y.shape[0]*2/3)
train_length
# Out:
# 2438

# %%
y.shape[0]-test_length
# Out:
# 1220

# %%
#通过2:1划分训练集和测试集，2/3为训练集
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,shuffle=False,random_state=13)

x_train.shape
# Out:
# (2450, 7)

# %%
#取得训练集，和测试集的格式——》(3,4)->(1,)通过3行历史数据5列目标特征预测1行1列的目标
# multivariate_data(x,y, start_index, end_index, history_size,target_size, step, single_step)
train_dataset,train_labels=multivariate_data(x_train,y_train,0,2450-10,10,7,1,True)
test_dataset,test_labels=multivariate_data(x_test,y_test,0,y.shape[0]-2450-10,10,7,1,True)

# %%
train_dataset.shape
# Out:
# (2430, 10, 7)

# %%
#创建训练组，内部的batch_size，buffer_size，shuffle，batch建议百度
#该函数目标是把刚建好的训练集/测试集转化成tensorflow的数据集格式，打乱分组方便训练模型......
def create_batch_dataset(x,y,train=True,buffer_size=1000,batch_size=128):
    batch_data=tf.data.Dataset.from_tensor_slices((tf.constant(x),tf.constant(y)))
    if train:
        return batch_data.cache().shuffle(buffer_size).batch(batch_size)
    else:
        return batch_data.batch(batch_size)
       
        
#使用上面函数
train_batch_dataset=create_batch_dataset(train_dataset,train_labels)
test_batch_dataset=create_batch_dataset(test_dataset,test_labels,train=False)
#拿一个测试集元素查看格式
list(test_batch_dataset.as_numpy_iterator())[0]
# Out:
# (array([[[ 0.725     ,  0.75555556,  0.        , ..., -0.70862668,
#           -0.70558361,  0.72727273],
#          [ 0.775     ,  0.75555556,  0.        , ..., -0.69637623,
#           -0.71767691,  0.72727273],
#          [ 0.65      ,  0.77777778,  0.        , ..., -0.68391942,
#           -0.72955755,  0.72727273],
#          ...,
#          [ 0.6       ,  0.71111111,  0.33333333, ..., -0.6186714 ,
#           -0.78564986,  0.72727273],
#          [ 0.7       ,  0.77777778,  0.        , ..., -0.60505607,
#           -0.79618286,  0.72727273],
#          [ 0.7       ,  0.77777778,  0.        , ..., -0.59126144,
#           -0.80647995,  0.72727273]],
#
#         [[ 0.775     ,  0.75555556,  0.        , ..., -0.69637623,
#           -0.71767691,  0.72727273],
#          [ 0.65      ,  0.77777778,  0.        , ..., -0.68391942,
#           -0.72955755,  0.72727273],
#          [ 0.675     ,  0.68888889,  0.        , ..., -0.67125996,
#           -0.74122201,  0.72727273],
#          ...,
#          [ 0.7       ,  0.77777778,  0.        , ..., -0.60505607,
#           -0.79618286,  0.72727273],
#          [ 0.7       ,  0.77777778,  0.        , ..., -0.59126144,
#           -0.80647995,  0.72727273],
#          [ 0.7       ,  0.68888889,  0.        , ..., -0.57729162,
#           -0.81653805,  0.72727273]],
#
#         [[ 0.65      ,  0.77777778,  0.        , ..., -0.68391942,
#           -0.72955755,  0.72727273],
#          [ 0.675     ,  0.68888889,  0.        , ..., -0.67125996,
#           -0.74122201,  0.72727273],
#          [ 0.675     ,  0.71111111,  0.        , ..., -0.65840158,
#           -0.75266683,  0.72727273],
#          ...,
#          [ 0.7       ,  0.77777778,  0.        , ..., -0.59126144,
#           -0.80647995,  0.72727273],
#          [ 0.7       ,  0.68888889,  0.        , ..., -0.57729162,
#           -0.81653805,  0.72727273],
#          [ 0.7       ,  0.71111111,  0.        , ..., -0.56315072,
#           -0.8263542 ,  0.72727273]],
#
#         ...,
#
#         [[ 0.2       ,  0.33333333,  0.        , ...,  0.94698775,
#            0.32126966,  0.        ],
#          [ 0.225     ,  0.33333333,  0.        , ...,  0.94131732,
#            0.3375229 ,  0.        ],
#          [ 0.3       ,  0.28888889,  0.        , ...,  0.93536795,
#            0.35367612,  0.        ],
#          ...,
#          [ 0.3       ,  0.24444444,  0.5       , ...,  0.90150168,
#            0.43277559,  0.        ],
#          [ 0.275     ,  0.24444444,  0.        , ...,  0.8939186 ,
#            0.44822934,  0.        ],
#          [ 0.225     ,  0.24444444,  0.        , ...,  0.88607062,
#            0.46355027,  0.        ]],
#
#         [[ 0.225     ,  0.33333333,  0.        , ...,  0.94131732,
#            0.3375229 ,  0.        ],
#          [ 0.3       ,  0.28888889,  0.        , ...,  0.93536795,
#            0.35367612,  0.        ],
#          [ 0.4       ,  0.28888889,  0.        , ...,  0.92914141,
#            0.36972454,  0.        ],
#          ...,
#          [ 0.275     ,  0.24444444,  0.        , ...,  0.8939186 ,
#            0.44822934,  0.        ],
#          [ 0.225     ,  0.24444444,  0.        , ...,  0.88607062,
#            0.46355027,  0.        ],
#          [ 0.225     ,  0.31111111,  0.        , ...,  0.87796008,
#            0.47873384,  0.        ]],
#
#         [[ 0.3       ,  0.28888889,  0.        , ...,  0.93536795,
#            0.35367612,  0.        ],
#          [ 0.4       ,  0.28888889,  0.        , ...,  0.92914141,
#            0.36972454,  0.        ],
#          [ 0.4       ,  0.33333333,  0.33333333, ...,  0.92263955,
#            0.38566341,  0.        ],
#          ...,
#          [ 0.225     ,  0.24444444,  0.        , ...,  0.88607062,
#            0.46355027,  0.        ],
#          [ 0.225     ,  0.31111111,  0.        , ...,  0.87796008,
#            0.47873384,  0.        ],
#          [ 0.2       ,  0.28888889,  0.33333333, ...,  0.86958939,
#            0.49377555,  0.        ]]]),
#  array([0.75 , 0.725, 0.625, 0.65 , 0.625, 0.6  , 0.65 , 0.7  , 0.675,
#         0.675, 0.65 , 0.55 , 0.475, 0.575, 0.55 , 0.525, 0.55 , 0.55 ,
#         0.6  , 0.625, 0.55 , 0.575, 0.575, 0.5  , 0.475, 0.45 , 0.475,
#         0.475, 0.475, 0.55 , 0.575, 0.55 , 0.475, 0.475, 0.55 , 0.5  ,
#         0.425, 0.45 , 0.45 , 0.55 , 0.6  , 0.375, 0.4  , 0.45 , 0.575,
#         0.425, 0.275, 0.3  , 0.475, 0.45 , 0.55 , 0.575, 0.4  , 0.275,
#         0.375, 0.325, 0.325, 0.375, 0.4  , 0.25 , 0.175, 0.225, 0.25 ,
#         0.325, 0.225, 0.225, 0.275, 0.325, 0.375, 0.3  , 0.35 , 0.375,
#         0.4  , 0.475, 0.5  , 0.375, 0.325, 0.225, 0.275, 0.375, 0.4  ,
#         0.375, 0.375, 0.4  , 0.2  , 0.2  , 0.25 , 0.3  , 0.125, 0.15 ,
#         0.25 , 0.375, 0.4  , 0.4  , 0.425, 0.375, 0.275, 0.275, 0.225,
#         0.325, 0.225, 0.225, 0.225, 0.2  , 0.225, 0.275, 0.225, 0.225,
#         0.2  , 0.225, 0.3  , 0.4  , 0.4  , 0.35 , 0.35 , 0.3  , 0.275,
#         0.225, 0.225, 0.2  , 0.2  , 0.325, 0.325, 0.3  , 0.275, 0.275,
#         0.3  , 0.325]))

# %%
#建立神经网络模型-3层LSTM和一个输出层
model= tf.keras.models.Sequential([
    tf.keras.layers.LSTM(256, input_shape=train_dataset.shape[-2:],return_sequences=True), # input_shape=(20,1) 不包含批处理维度
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.LSTM(128, return_sequences=True),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.LSTM(32),
    tf.keras.layers.Dense(1)
])

#优化器和损失函数设置
model.compile(optimizer='adam',loss='mse')

#模型保存的相关设置
utils.plot_model(model)
checkpoint_file='test_model.hdf5'
checkpoint_callback=ModelCheckpoint(filepath=checkpoint_file,monitor='loss',moode='min',save_best_only=True,save_weights_only=True)
#模型训练
history=model.fit(train_batch_dataset,epochs=30,validation_data=test_batch_dataset,callbacks=[checkpoint_callback])
# Out:
# Failed to import pydot. You must install pydot and graphviz for `pydotprint` to work.
# Train for 19 steps, validate for 10 steps
# Epoch 1/30
# 19/19 [==============================] - 4s 220ms/step - loss: 0.0425 - val_loss: 0.0091
# Epoch 2/30
# 19/19 [==============================] - 1s 65ms/step - loss: 0.0096 - val_loss: 0.0083
# Epoch 3/30
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0076 - val_loss: 0.0088
# Epoch 4/30
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0068 - val_loss: 0.0082
# Epoch 5/30
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0066 - val_loss: 0.0084
# Epoch 6/30
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0066 - val_loss: 0.0078
# Epoch 7/30
# 19/19 [==============================] - 1s 63ms/step - loss: 0.0066 - val_loss: 0.0079
# Epoch 8/30
# 19/19 [==============================] - 1s 63ms/step - loss: 0.0066 - val_loss: 0.0073
# Epoch 9/30
# 19/19 [==============================] - 1s 63ms/step - loss: 0.0065 - val_loss: 0.0073
# Epoch 10/30
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0065 - val_loss: 0.0076
# Epoch 11/30
# 19/19 [==============================] - 1s 64ms/step - loss: 0.0064 - val_loss: 0.0074
# Epoch 12/30
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0065 - val_loss: 0.0078
# Epoch 13/30
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0064 - val_loss: 0.0074
# Epoch 14/30
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0060 - val_loss: 0.0075
# Epoch 15/30
# 19/19 [==============================] - 1s 60ms/step - loss: 0.0062 - val_loss: 0.0075
# Epoch 16/30
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0061 - val_loss: 0.0073
# Epoch 17/30
# 19/19 [==============================] - 1s 63ms/step - loss: 0.0062 - val_loss: 0.0076
# Epoch 18/30
# 19/19 [==============================] - 1s 65ms/step - loss: 0.0064 - val_loss: 0.0072
# Epoch 19/30
# 19/19 [==============================] - 1s 66ms/step - loss: 0.0062 - val_loss: 0.0076
# Epoch 20/30
# 19/19 [==============================] - 1s 65ms/step - loss: 0.0063 - val_loss: 0.0071
# Epoch 21/30
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0066 - val_loss: 0.0072
# Epoch 22/30
# 19/19 [==============================] - 1s 60ms/step - loss: 0.0064 - val_loss: 0.0075
# Epoch 23/30
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0061 - val_loss: 0.0081
# Epoch 24/30
# 19/19 [==============================] - 1s 63ms/step - loss: 0.0060 - val_loss: 0.0074
# Epoch 25/30
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0060 - val_loss: 0.0071
# Epoch 26/30
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0061 - val_loss: 0.0079
# Epoch 27/30
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0062 - val_loss: 0.0072
# Epoch 28/30
# 19/19 [==============================] - 1s 62ms/step - loss: 0.0059 - val_loss: 0.0088
# Epoch 29/30
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0060 - val_loss: 0.0071
# Epoch 30/30
# 19/19 [==============================] - 1s 61ms/step - loss: 0.0060 - val_loss: 0.0073

# %%
#最喜欢的绘图环节，通过history获取模型每步训练取得的结果loss和val_loss
plt.figure(figsize=(8,8),dpi=200)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model train vs validation loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train','validation'], loc='best')
plt.show()

# %%
test_dataset.shape
# Out:
# (1188, 10, 7)

# %%
#通过输入一组数据预测
test_preds=model.predict(test_dataset,verbose=1)
test_preds[:10]
# Out:
# 1188/1188 [==============================] - 1s 659us/sample
# array([[0.64286757],
#        [0.64084625],
#        [0.63840616],
#        [0.63778055],
#        [0.6359565 ],
#        [0.6335577 ],
#        [0.62064606],
#        [0.61171407],
#        [0.6040674 ],
#        [0.6017838 ]], dtype=float32)

# %%
#将预测后的一组数据转化为1维方便比较
test_preds=test_preds[:,0]
test_preds[:10]
# Out:
# array([0.64286757, 0.64084625, 0.63840616, 0.63778055, 0.6359565 ,
#        0.6335577 , 0.62064606, 0.61171407, 0.6040674 , 0.6017838 ],
#       dtype=float32)

# %%
#pred = np.insert(test_dataset, 13, values=test_preds, axis=1)
# df_preds = pd.DataFrame(test_preds)
# test_inverse = scaler.inverse_transform(df_preds.values)
# test_inverse
reverse_preds = [i*(normalize_info["Tem_Low"]["Tem_Low_Max"]-normalize_info["Tem_Low"]["Tem_Low_Min"])+normalize_info["Tem_Low"]["Tem_Low_Min"]  for i in test_preds]
reverse_preds
# Out:
# [16.714702606201172,
#  16.63385009765625,
#  16.536246299743652,
#  16.511221885681152,
#  16.438261032104492,
#  16.342307090759277,
#  15.825842380523682,
#  15.468562602996826,
#  15.162695407867432,
#  15.071352481842041,
#  14.961219787597656,
#  14.825695514678955,
#  14.666672706604004,
#  14.50360631942749,
#  14.320775032043457,
#  14.136124610900879,
#  13.528045177459717,
#  13.316980361938477,
#  13.130444049835205,
#  12.663470268249512,
#  12.161746978759766,
#  11.91029167175293,
#  11.648245811462402,
#  11.414049625396729,
#  11.163264274597168,
#  10.907360076904297,
#  10.678915739059448,
#  10.458345174789429,
#  10.271152019500732,
#  9.65778923034668,
#  9.556941747665405,
#  9.312588930130005,
#  9.048570156097412,
#  8.775013446807861,
#  8.482736110687256,
#  8.228367328643799,
#  7.975953578948975,
#  7.746917963027954,
#  7.6527533531188965,
#  7.573514938354492,
#  7.494379043579102,
#  7.402428150177002,
#  7.29656195640564,
#  6.848652124404907,
#  6.717231035232544,
#  6.567314624786377,
#  6.417431592941284,
#  6.18399715423584,
#  5.9918437004089355,
#  5.8374927043914795,
#  5.7658467292785645,
#  5.716309309005737,
#  5.632381200790405,
#  5.609613418579102,
#  5.572404623031616,
#  5.407143592834473,
#  4.848614692687988,
#  4.57887864112854,
#  4.318452835083008,
#  3.8270375728607178,
#  3.959192991256714,
#  14.24803113937378,
#  13.882769107818604,
#  13.54030704498291,
#  13.089030742645264,
#  12.560437679290771,
#  12.279420852661133,
#  12.016967296600342,
#  11.579087734222412,
#  11.12101411819458,
#  10.651591777801514,
#  10.152412414550781,
#  10.047482013702393,
#  9.702982664108276,
#  9.312516212463379,
#  9.041307926177979,
#  9.081839084625244,
#  8.70505428314209,
#  8.292964458465576,
#  8.23276138305664,
#  8.148020267486572,
#  8.04124927520752,
#  7.63799524307251,
#  7.692287921905518,
#  7.777172088623047,
#  7.868479251861572,
#  7.94598913192749,
#  7.882812976837158,
#  7.766328811645508,
#  7.613984107971191,
#  7.054098606109619,
#  6.542318820953369,
#  6.08808970451355,
#  5.955389499664307,
#  5.823487997055054,
#  5.360370635986328,
#  5.015262126922607,
#  4.745847940444946,
#  4.364609479904175,
#  4.393669128417969,
#  3.973073720932007,
#  3.8263890743255615,
#  3.6333236694335938,
#  3.422846555709839,
#  3.1744346618652344,
#  3.0214951038360596,
#  2.8604397773742676,
#  2.8170583248138428,
#  2.891498565673828,
#  2.864776611328125,
#  2.3961410522460938,
#  2.584494113922119,
#  2.678820848464966,
#  2.3870668411254883,
#  2.5615129470825195,
#  2.6757655143737793,
#  2.3590049743652344,
#  2.031832695007324,
#  2.20461106300354,
#  1.994112491607666,
#  1.8580076694488525,
#  1.5830156803131104,
#  1.6633937358856201,
#  1.7243728637695312,
#  1.7914113998413086,
#  1.8811545372009277,
#  1.4765069484710693,
#  1.3459358215332031,
#  1.2867531776428223,
#  1.239654779434204,
#  0.7303992509841919,
#  0.4204920530319214,
#  0.5294910669326782,
#  0.5231926441192627,
#  0.30718958377838135,
#  0.2154008150100708,
#  0.19781982898712158,
#  0.09787595272064209,
#  0.005623459815979004,
#  -0.042284369468688965,
#  0.03734266757965088,
#  0.09378528594970703,
#  0.03441488742828369,
#  -0.28938615322113037,
#  -0.617668867111206,
#  -0.5645354986190796,
#  -0.6051024198532104,
#  -0.6205728054046631,
#  -0.5279346704483032,
#  -0.4944976568222046,
#  -0.5968769788742065,
#  -0.21746718883514404,
#  0.11266028881072998,
#  0.3739420175552368,
#  0.13572490215301514,
#  -0.037090420722961426,
#  -0.07496201992034912,
#  0.22676026821136475,
#  0.4525796175003052,
#  0.7525221109390259,
#  0.7385960817337036,
#  1.0306916236877441,
#  1.3471589088439941,
#  1.690748691558838,
#  1.9840011596679688,
#  2.257215738296509,
#  2.5157508850097656,
#  2.8601834774017334,
#  3.209705114364624,
#  3.3574447631835938,
#  3.4852561950683594,
#  3.512383460998535,
#  3.4130845069885254,
#  3.463775873184204,
#  3.1502935886383057,
#  2.901954412460327,
#  2.2717533111572266,
#  1.5782997608184814,
#  0.7796481847763062,
#  0.24453318119049072,
#  -0.17256581783294678,
#  -0.5306860208511353,
#  -0.24516785144805908,
#  -0.20745837688446045,
#  0.21078026294708252,
#  0.6943134069442749,
#  1.1768851280212402,
#  1.565875768661499,
#  1.8285367488861084,
#  1.7630813121795654,
#  1.892794132232666,
#  1.9950947761535645,
#  1.8380484580993652,
#  2.0023558139801025,
#  2.291811466217041,
#  2.3544118404388428,
#  2.6899311542510986,
#  3.028627395629883,
#  3.1780824661254883,
#  3.359459400177002,
#  3.6607394218444824,
#  4.151998519897461,
#  4.659987449645996,
#  5.1356706619262695,
#  5.650944471359253,
#  6.090925693511963,
#  6.455727577209473,
#  6.865849256515503,
#  7.189478635787964,
#  7.547882556915283,
#  7.977381706237793,
#  8.430572509765625,
#  8.719197273254395,
#  9.053534030914307,
#  9.321435451507568,
#  9.424705266952515,
#  9.610341548919678,
#  9.690063953399658,
#  9.524984121322632,
#  9.44089150428772,
#  9.17009449005127,
#  9.061997890472412,
#  9.052562475204468,
#  9.142170906066895,
#  9.388493061065674,
#  9.685901165008545,
#  9.837326765060425,
#  10.178121089935303,
#  10.449604749679565,
#  10.667917490005493,
#  10.759471416473389,
#  10.872572422027588,
#  11.07214069366455,
#  11.133421421051025,
#  11.148077011108398,
#  11.356204509735107,
#  11.54140567779541,
#  11.738317966461182,
#  12.052112579345703,
#  12.2880539894104,
#  12.64440631866455,
#  12.934945583343506,
#  13.30078935623169,
#  13.528088092803955,
#  13.59889841079712,
#  13.649760246276855,
#  13.658214569091797,
#  13.67935037612915,
#  13.647864818572998,
#  13.682907581329346,
#  13.877426147460938,
#  14.130853176116943,
#  14.357441425323486,
#  14.506219387054443,
#  14.688485622406006,
#  14.851947784423828,
#  15.133756160736084,
#  15.318933486938477,
#  15.487881660461426,
#  15.619560241699219,
#  15.691934585571289,
#  15.685297012329102,
#  15.799628257751465,
#  15.93157148361206,
#  16.062828063964844,
#  16.221984386444092,
#  16.452747344970703,
#  16.724401473999023,
#  16.969538688659668,
#  17.137988567352295,
#  17.327977180480957,
#  17.461312770843506,
#  17.59733772277832,
#  17.753475666046143,
#  17.807985305786133,
#  17.949820518493652,
#  18.110273838043213,
#  18.201614379882812,
#  18.3508620262146,
#  18.479429244995117,
#  18.58955717086792,
#  18.717702388763428,
#  18.950596809387207,
#  19.213906288146973,
#  19.345484733581543,
#  19.587703704833984,
#  19.816158771514893,
#  19.93152952194214,
#  20.002556800842285,
#  20.214272499084473,
#  20.4301176071167,
#  20.638144969940186,
#  20.73310947418213,
#  20.86180305480957,
#  21.104308128356934,
#  21.2286958694458,
#  21.47534942626953,
#  21.672454833984375,
#  21.746324062347412,
#  21.795040130615234,
#  22.008400917053223,
#  22.088314056396484,
#  22.27868413925171,
#  22.35303258895874,
#  22.433250904083252,
#  22.490893363952637,
#  22.57789707183838,
#  ...]

# %%
len(reverse_preds)
# Out:
# 1188

# %%
test_value = dataset['Tem_Low'].values[2450:-20]
len(test_value)
# Out:
# 1188

# %%
sum = 0
for i in range(464):
    sum+=abs(reverse_preds[i]-test_value[i])
sum/464
# Out:
# 3.3823583871126175

# %%
#r2检验，越接近1效果越好，负数表示完全没用......
score=r2_score(test_labels,test_preds)
score
# Out:
# 0.8659484992362274

# %%
#做出预测结果和实际结果的曲线对比，使用1000次结果对比
plt.figure(figsize=(16,8))
plt.plot(test_value[:1000],label="True value")
plt.plot(reverse_preds[:1000],label="Pred value")
plt.legend(loc='best')
plt.show()
